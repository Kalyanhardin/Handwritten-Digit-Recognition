# %%
import pandas as pd

# %%
pd.DataFrame({"ok" : [12,34],"yes":[45,76]})
# Out:
#    ok  yes
# 0  12   45
# 1  34   76

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 653.6 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 871.5 kB/s eta 0:00:01
#    ---------------------- ----------------- 163.8/294.9 kB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 225.3/294.9 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
tips_data = sns.load_dataset("tips")
tips_data.columns
print(tips_data)
# tips_data['total_bill']

tips_data['total_bill'].min()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# 3.07

# %%
tips_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.countplot(data = tips_data, x="sex" ,hue= "day")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.relplot( x="total_bill", y="tip",kind = "scatter",data=tips_data,hue="sex")

# %%
tips_data.groupby("sex")["total_bill"].mean()
# Out:
# C:\Users\kalya\AppData\Local\Temp\ipykernel_11612\3288265262.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_data.groupby("sex")["total_bill"].mean()
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64
