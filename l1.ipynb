# %%
import matplotlib.pyplot as plt
import numpy as np
values=np.random.randn(100)
plt.plot(values)
plt.show()

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      ---- -------------------------------- 20.5/162.8 kB 640.0 kB/s eta 0:00:01
#      ---------------- -------------------- 71.7/162.8 kB 563.7 kB/s eta 0:00:01
#      ---------------------- ------------- 102.4/162.8 kB 653.6 kB/s eta 0:00:01
#      ------------------------------------ 162.8/162.8 kB 886.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.7 MB 3.0 MB/s eta 0:00:03
#     --------------------------------------- 0.2/7.7 MB 2.0 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/7.7 MB 2.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/7.7 MB 2.9 MB/s eta 0:00:03
# ...
